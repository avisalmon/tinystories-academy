# %% [markdown]
# # Lesson 1: Setup Check
#
# Run every cell from top to bottom with Shift+Enter. If they all run without errors,
# your environment is ready and you can move on to Lesson 2.

# %% [markdown]
# ## Python

# %%
import sys
print("Python:", sys.version.split()[0])
assert sys.version_info >= (3, 8), "Please use Python 3.8 or newer"

# %% [markdown]
# ## PyTorch

# %%
import torch
print("PyTorch:", torch.__version__)

# %% [markdown]
# ## NumPy and a quick plot

# %%
import numpy as np
import matplotlib.pyplot as plt

print("NumPy:", np.__version__)

xs = np.linspace(0, 6.28, 100)
plt.plot(xs, np.sin(xs))
plt.title("If you can see this curve, plotting works")
plt.show()

# %% [markdown]
# ## A tiny tensor
# A first taste of Lesson 2.

# %%
x = torch.randn(2, 3)
print("x =")
print(x)
print("shape:", x.shape)

# %% [markdown]
# ## Is the dataset here?

# %%
from pathlib import Path

candidates = [Path("data/stories"), Path("../data/stories")]
found = next((p for p in candidates if p.exists()), None)
if found:
    n = len(list(found.glob("*.txt")))
    print("Found dataset at", found, "with", n, "story files")
else:
    print("Dataset folder not found. Launch jupyter from the repo root so the paths line up.")

# %% [markdown]
# ## All set
#
# If every cell above ran without errors, your environment is ready. Continue to
# Lesson 2: Tensors and Shapes, and open notebook `02`.
